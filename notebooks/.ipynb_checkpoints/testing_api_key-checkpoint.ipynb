# %% [markdown]
# # Test API Key

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()

key = os.getenv("OPENAI_API_KEY")
if key:
    print(f"Key loaded! Starts with: {key[:8]}...")
else:
    print("ERROR: Key not found. Check your .env file.")
# Out:
# Key loaded! Starts with: sk-proj-...
